# %%
import numpy as np
import pandas as pd
import os
import json
import glob
import sys
from tqdm import tqdm
from IPython.display import FileLink

# %%
sys.path.insert(0, "../")

root_path = '/kaggle/input/CORD-19-research-challenge'

# Initialize a dictionary with the following 5 keys corresponding to the 5 features of the final dataframe.
covid_features = {"doc_id": [None], "title": [None], "abstract": [None], "text_body": [None]}

# Construct a dataframe from the dictionary. 
covid_df = pd.DataFrame.from_dict(covid_features)

# Import all files from the project directory which end with .json.
json_filenames = glob.glob(f'{root_path}/**/*.json', recursive=True)

# %% [markdown]
# # Dataset construction of 10000 documents.

# %%
def return_covid_df_10000(json_filenames, df):
    
    for file_name in tqdm(json_filenames[20000:30000]): # Use only 10000 documents.

        row = {}

        with open(file_name) as json_data:
            data = json.load(json_data)

            # Store the document id and title as values in the 'row' dictionary.
            doc_id = data['paper_id']
            row['doc_id'] = doc_id
            row['title'] = data['metadata']['title']

            # Store the document abstract as a value in the 'row' dictionary. 
            # Put it all in a list,then use str.join() to split it into paragraphs. 
            try:
                abstract_list = [abst['text'] for abst in data['abstract']]
                abstract = "\n ".join(abstract_list)
                row['abstract'] = abstract
                
            except: # Ignore documents which have nan as values for the abstract.
                row['abstract'] = np.nan
                
            # Store the document body text as a value in the 'row' dictionary.  
            # Perform the same operations as for the abstract.
            body_list = [bt['text'] for bt in data['body_text']]
            body = "\n ".join(body_list)
            row['text_body'] = body
            
            # Append each 'row' dictionary to the dataframe.
            df = df.append(row, ignore_index=True)
                 
    return df

# %%
covid_df_10000 = return_covid_df_10000(json_filenames,covid_df)
covid_df_10000
# Out:
# 100%|██████████| 10000/10000 [01:34<00:00, 106.10it/s]
#                                          doc_id  \
# 0                                          None
# 1      5ac635d21fdb1726f21d7090a233dd2b5ffdc1b5
# 2      71d93a6452061c57ae1532991d4a20cd6fc6fcb3
# 3      635ba7eca764f7caaa82904197c40a20111ec940
# 4      0282d2f9eb65318e40db21efbe6172ce16c8acf5
# ...                                         ...
# 9996   e6fe93e18fe7e74cc6d90086205e877c4245df35
# 9997   a6f37939b6a069def17ff724d2d49bbb41ce8f82
# 9998   8126a598911ae325a6ebf1e1ca2fb9ae08cc73a2
# 9999   cc3f4dc92499c431d05f71a9a4d0e74704f0a30b
# 10000  b594e053943d9bc612404581d1a5ea20994567de
#
#                                                    title  \
# 0                                                   None
# 1      Long Term Predictors of Breathlessness, Exerci...
# 2      Emergence of universality in the transmission ...
# 3      Supporting families to protect child health: P...
# 4      Perspectives on the Early Quality of Evidence ...
# ...                                                  ...
# 9996   Journal Pre-proof Targeted delivery of inhalab...
# 9997
# 9998
# 9999   Surveillance of acute SARS-CoV-2 infections in...
# 10000         IMPACTS OF COVID-19 ON GLOBAL VALUE CHAINS
#
#                                                 abstract  \
# 0                                                   None
# 1                       J o u r n a l P r e -p r o o f 2
# 2      The complexities involved in modelling the tra...
# 3      Supportive parenting is critical for promoting...
# 4      Background: The severe acute respiratory syndr...
# ...                                                  ...
# 9996   The coronavirus disease 2019 pandemic has led ...
# 9997   Governments around the globe have started to d...
# 9998
# 9999   Background: Switzerland had one of the highest...
# 10000  We investigate the impacts of COVID-19 on glob...
#
#                                                text_body
# 0                                                   None
# 1      With over 246 million Coronavirus disease 2019...
# 2      • Even though the pattern of disease spread is...
# 3      a1111111111 a1111111111 a1111111111 a111111111...
# 4      The severe acute respiratory syndrome coronavi...
# ...                                                  ...
# 9996   Coronavirus disease 2019 (COVID-19) is highly ...
# 9997   The novel coronavirus , first detected late 20...
# 9998   as a means of preventing transmission (Chu et ...
# 9999   The role of schools in severe acute respirator...
# 10000  T HE ongoing coronavirus pandemic (hereinafter...
#
# [10001 rows x 4 columns]

# %%
covid_df_10000.isnull().sum(axis = 0) # Check if there any missing values in the columns. We are interested in the 'text_body' column.
# Out:
# doc_id       1
# title        1
# abstract     1
# text_body    1
# dtype: int64

# %%
covid_df_10000.dropna(subset=['text_body'],inplace=True) # Drop rows with missing values for the 'text_body' column.
covid_df_10000
# Out:
#                                          doc_id  \
# 1      5ac635d21fdb1726f21d7090a233dd2b5ffdc1b5
# 2      71d93a6452061c57ae1532991d4a20cd6fc6fcb3
# 3      635ba7eca764f7caaa82904197c40a20111ec940
# 4      0282d2f9eb65318e40db21efbe6172ce16c8acf5
# 5      d96113a2d8691d3b1aee5fd1b5d30241f2b2a633
# ...                                         ...
# 9996   e6fe93e18fe7e74cc6d90086205e877c4245df35
# 9997   a6f37939b6a069def17ff724d2d49bbb41ce8f82
# 9998   8126a598911ae325a6ebf1e1ca2fb9ae08cc73a2
# 9999   cc3f4dc92499c431d05f71a9a4d0e74704f0a30b
# 10000  b594e053943d9bc612404581d1a5ea20994567de
#
#                                                    title  \
# 1      Long Term Predictors of Breathlessness, Exerci...
# 2      Emergence of universality in the transmission ...
# 3      Supporting families to protect child health: P...
# 4      Perspectives on the Early Quality of Evidence ...
# 5      Quantify the role of superspreaders -opinion l...
# ...                                                  ...
# 9996   Journal Pre-proof Targeted delivery of inhalab...
# 9997
# 9998
# 9999   Surveillance of acute SARS-CoV-2 infections in...
# 10000         IMPACTS OF COVID-19 ON GLOBAL VALUE CHAINS
#
#                                                 abstract  \
# 1                       J o u r n a l P r e -p r o o f 2
# 2      The complexities involved in modelling the tra...
# 3      Supportive parenting is critical for promoting...
# 4      Background: The severe acute respiratory syndr...
# 5      Effective communication of accurate informatio...
# ...                                                  ...
# 9996   The coronavirus disease 2019 pandemic has led ...
# 9997   Governments around the globe have started to d...
# 9998
# 9999   Background: Switzerland had one of the highest...
# 10000  We investigate the impacts of COVID-19 on glob...
#
#                                                text_body
# 1      With over 246 million Coronavirus disease 2019...
# 2      • Even though the pattern of disease spread is...
# 3      a1111111111 a1111111111 a1111111111 a111111111...
# 4      The severe acute respiratory syndrome coronavi...
# 5      We design a mathematical model to quantify the...
# ...                                                  ...
# 9996   Coronavirus disease 2019 (COVID-19) is highly ...
# 9997   The novel coronavirus , first detected late 20...
# 9998   as a means of preventing transmission (Chu et ...
# 9999   The role of schools in severe acute respirator...
# 10000  T HE ongoing coronavirus pandemic (hereinafter...
#
# [10000 rows x 4 columns]

# %% [markdown]
# # Dataset construction of 20000 documents.

# %%
def return_covid_df_20000(json_filenames, df):
    
    for file_name in tqdm(json_filenames[20000:40000]): # Use only 20000 documents.

        row = {}

        with open(file_name) as json_data:
            data = json.load(json_data)

            # Store the document id and title as values in the 'row' dictionary.
            doc_id = data['paper_id']
            row['doc_id'] = doc_id
            row['title'] = data['metadata']['title']

            # Store the document abstract as a value in the 'row' dictionary. 
            # Put it all in a list,then use str.join() to split it into paragraphs. 
            try:
                abstract_list = [abst['text'] for abst in data['abstract']]
                abstract = "\n ".join(abstract_list)
                row['abstract'] = abstract
                
            except: # Ignore documents which have nan as values for the abstract.
                row['abstract'] = np.nan
                
            # Store the document body text as a value in the 'row' dictionary.  
            # Perform the same operations as for the abstract.
            body_list = [bt['text'] for bt in data['body_text']]
            body = "\n ".join(body_list)
            row['text_body'] = body
            
            # Append each 'row' dictionary to the dataframe.
            df = df.append(row, ignore_index=True)
                 
    return df

# %%
covid_df_20000 = return_covid_df_20000(json_filenames,covid_df)
covid_df_20000
# Out:
# 100%|██████████| 20000/20000 [02:50<00:00, 117.63it/s]
#                                          doc_id  \
# 0                                          None
# 1      5ac635d21fdb1726f21d7090a233dd2b5ffdc1b5
# 2      71d93a6452061c57ae1532991d4a20cd6fc6fcb3
# 3      635ba7eca764f7caaa82904197c40a20111ec940
# 4      0282d2f9eb65318e40db21efbe6172ce16c8acf5
# ...                                         ...
# 19996  ffdc50d239f8e531dc159993723c0cbc176a632e
# 19997  b37bf3ab1d814f853a42cd8958d7390b42343bd2
# 19998  2c70b8caf708c5c1b0c9b811a80179061274cff7
# 19999  1831d9c801bcbc3388eb2aeb7d48aed3c2c690e9
# 20000  fcc20ac2565227911768f685af57ebdb79f827c2
#
#                                                    title  \
# 0                                                   None
# 1      Long Term Predictors of Breathlessness, Exerci...
# 2      Emergence of universality in the transmission ...
# 3      Supporting families to protect child health: P...
# 4      Perspectives on the Early Quality of Evidence ...
# ...                                                  ...
# 19996  Comparative analysis of antibody-and lipid-bas...
# 19997
# 19998                                       Nervensystem
# 19999  Journal Pre-proof The sub-specialty of Foot an...
# 20000  Lunge und Beatmung NIV, Weaning, Monitoring 00...
#
#                                                 abstract  \
# 0                                                   None
# 1                       J o u r n a l P r e -p r o o f 2
# 2      The complexities involved in modelling the tra...
# 3      Supportive parenting is critical for promoting...
# 4      Background: The severe acute respiratory syndr...
# ...                                                  ...
# 19996  Multiplexing of samples in single-cell RNA-seq...
# 19997
# 19998
# 19999
# 20000  Objective: There is an increasing incidence of...
#
#                                                text_body
# 0                                                   None
# 1      With over 246 million Coronavirus disease 2019...
# 2      • Even though the pattern of disease spread is...
# 3      a1111111111 a1111111111 a1111111111 a111111111...
# 4      The severe acute respiratory syndrome coronavi...
# ...                                                  ...
# 19996  Recent advances in single-cell and single-nucl...
# 19997  To the Editor:\n We read with interest the art...
# 19998  zeichen diagnostisch eine Rolle spielen. Am Ko...
# 19999  The sub-specialty of Foot and Ankle is evolvin...
# 20000  Sauerstoffmaske (Intersurgical Ltd., Berkshire...
#
# [20001 rows x 4 columns]

# %%
covid_df_20000.isnull().sum(axis = 0) # Check if there any missing values in the columns. We are interested in the 'text_body' column.
# Out:
# doc_id       1
# title        1
# abstract     1
# text_body    1
# dtype: int64

# %%
covid_df_20000.dropna(subset=['text_body'],inplace=True) # Drop rows with missing values for the 'text_body' column.
covid_df_20000
# Out:
#                                          doc_id  \
# 1      5ac635d21fdb1726f21d7090a233dd2b5ffdc1b5
# 2      71d93a6452061c57ae1532991d4a20cd6fc6fcb3
# 3      635ba7eca764f7caaa82904197c40a20111ec940
# 4      0282d2f9eb65318e40db21efbe6172ce16c8acf5
# 5      d96113a2d8691d3b1aee5fd1b5d30241f2b2a633
# ...                                         ...
# 19996  ffdc50d239f8e531dc159993723c0cbc176a632e
# 19997  b37bf3ab1d814f853a42cd8958d7390b42343bd2
# 19998  2c70b8caf708c5c1b0c9b811a80179061274cff7
# 19999  1831d9c801bcbc3388eb2aeb7d48aed3c2c690e9
# 20000  fcc20ac2565227911768f685af57ebdb79f827c2
#
#                                                    title  \
# 1      Long Term Predictors of Breathlessness, Exerci...
# 2      Emergence of universality in the transmission ...
# 3      Supporting families to protect child health: P...
# 4      Perspectives on the Early Quality of Evidence ...
# 5      Quantify the role of superspreaders -opinion l...
# ...                                                  ...
# 19996  Comparative analysis of antibody-and lipid-bas...
# 19997
# 19998                                       Nervensystem
# 19999  Journal Pre-proof The sub-specialty of Foot an...
# 20000  Lunge und Beatmung NIV, Weaning, Monitoring 00...
#
#                                                 abstract  \
# 1                       J o u r n a l P r e -p r o o f 2
# 2      The complexities involved in modelling the tra...
# 3      Supportive parenting is critical for promoting...
# 4      Background: The severe acute respiratory syndr...
# 5      Effective communication of accurate informatio...
# ...                                                  ...
# 19996  Multiplexing of samples in single-cell RNA-seq...
# 19997
# 19998
# 19999
# 20000  Objective: There is an increasing incidence of...
#
#                                                text_body
# 1      With over 246 million Coronavirus disease 2019...
# 2      • Even though the pattern of disease spread is...
# 3      a1111111111 a1111111111 a1111111111 a111111111...
# 4      The severe acute respiratory syndrome coronavi...
# 5      We design a mathematical model to quantify the...
# ...                                                  ...
# 19996  Recent advances in single-cell and single-nucl...
# 19997  To the Editor:\n We read with interest the art...
# 19998  zeichen diagnostisch eine Rolle spielen. Am Ko...
# 19999  The sub-specialty of Foot and Ankle is evolvin...
# 20000  Sauerstoffmaske (Intersurgical Ltd., Berkshire...
#
# [20000 rows x 4 columns]

# %% [markdown]
# # Download the datasets.

# %%
os.chdir("/kaggle/working/")

# %%
covid_df_10000.to_csv(r'covid_df_10000.csv')

# %%
FileLink(r'covid_df_10000.csv')
# Out:
# /kaggle/working/covid_df_10000.csv

# %%
covid_df_20000.to_csv(r'covid_df_20000.csv')

# %%
FileLink(r'covid_df_20000.csv')
# Out:
# /kaggle/working/covid_df_20000.csv
